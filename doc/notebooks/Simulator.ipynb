# %%
# %run ../../simulate.py run --conf=philharmonic.settings.simple
# Out:
# INFO:root:
# SETTINGS
# ########
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# C:\Users\Andreas\Dropbox\uni\DA\Implementation\philharmonic\simulate.py in <module>()
#      65 if __name__ == "__main__":
#      66     #load_settings_run()
# ---> 67     cli()
#
# c:\Users\Andreas\Anaconda\lib\site-packages\click\core.pyc in __call__(self, *args, **kwargs)
#     608     def __call__(self, *args, **kwargs):
#     609         """Alias for :meth:`main`."""
# --> 610         return self.main(*args, **kwargs)
#     611
#     612
#
# c:\Users\Andreas\Anaconda\lib\site-packages\click\core.pyc in main(self, args, prog_name, complete_var, standalone_mode, **extra)
#     588             try:
#     589                 with self.make_context(prog_name, args, **extra) as ctx:
# --> 590                     rv = self.invoke(ctx)
#     591                     if not standalone_mode:
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
