# %%
import urllib2
import json

url = 'http://localhost:8081/em-app/rest/em'
response = urllib2.urlopen(url).read()
response
# Out:
# '[{"id":3,"name":"Belpex","description":"Energy market responsible for managing spot prices in the Belgian region"},{"id":2,"name":"ISO-NE","description":"Energy market responsible for managing spot prices in the New England region"},{"id":1,"name":"Nord Pool Spot","description":"Spot Market responsible for bidding area of northern europe"}]'

# %%
json.load(urllib2.urlopen(url))
# Out:
# [{u'description': u'Energy market responsible for managing spot prices in the Belgian region',
#   u'id': 3,
#   u'name': u'Belpex'},
#  {u'description': u'Energy market responsible for managing spot prices in the New England region',
#   u'id': 2,
#   u'name': u'ISO-NE'},
#  {u'description': u'Spot Market responsible for bidding area of northern europe',
#   u'id': 1,
#   u'name': u'Nord Pool Spot'}]

# %%
url = 'http://localhost:8081/em-app/rest/r/forecast/1/2014-07-07/2014-07-10'
urllib2.urlopen(url).read()
# Out:
# 'Forecast result: \n[23.775937281751826, 23.40561825494377, 23.501101361564785, 25.79895274386726, 29.363679090684535, 32.29230040633685, 33.63681414504735, 34.8817758117938, 34.95340591646604, 35.24008453882007, 34.64861345609743, 33.72235220122791, 33.703301122125886, 33.74794282754794, 33.226009485248085, 32.953773608454185, 33.272483122132705, 33.35247577479721, 32.1369976217697, 32.63485370924957, 32.63220780726069, 29.739149987715493, 27.563715781098782, 25.997727192616896, 25.579354292452738, 25.451620937038097, 25.227856037512446, 27.025617683313133, 31.073755188107807, 34.26888883859448, 35.24673912071993, 36.21109738907272, 36.09616019276936, 36.348174802748964, 35.74858204343556, 34.25250116948393, 34.04204243799777, 33.45646698973968, 32.72890393773158, 32.25534131566636, 32.44605544485477, 32.57107139258333, 31.42107460434055, 31.86813504211156, 31.783285884083977, 28.965562999259554, 27.456113961472774, 26.264875575059303, 23.18245609024607, 22.961581497543612, 23.0909096337343, 25.42067888030313, 29.46080550652337, 32.195931036091295, 33.29005186209223, 35.06966079337342, 35.1482465961591, 35.23877499681526, 34.67621044897355, 33.974848902749834, 34.7211488176167, 35.01981688480797, 34.95191869361616, 34.348772422924924, 34.24360048327855, 34.53193610916848, 33.2387046279626, 34.06249005939123, 33.927659390913306, 29.31889372181766, 27.03400103394309, 25.494195366547476, 21.05282820847285, 20.8124605635913, 21.145669061987704, 23.487946550154042, 29.12883052280356, 32.091305215569164, 32.682431481617876, 34.34796483635204, 34.814654878998276, 35.09215872224327, 34.74738040956856, 33.99311712099811, 34.09148084526119, 34.22800186573537, 34.12805400772814, 33.768917061663096, 34.16419009545404, 34.40725229128328, 32.854326198818036, 33.53216633179461, 33.064767736546735, 27.520993058434673, 25.76117696403285, 23.936239023321832]'

# %%
import urllib2
url3 = 'http://localhost:8081/em-app/rest/daprices/price/csv/1/2014-07-07%2000:00:00/2014-07-20%2023:00:00'
csv_data = urllib2.urlopen(url3).read()
csv_data2 = ',Helsinki\r\n2014-07-07 00:00:00.0,24.43\r\n2014-07-07 01:00:00.0,24.23\r\n2014-07-07 02:00:00.0,24.38\r\n2014-07-07 03:00:00.0,24.14\r\n2014-07-07 04:00:00.0,26.02\r\n'

# %%
csv_data2 = ',Helsinki\r\n2014-07-07 00:00:00.0,24.43\r\n2014-07-07 01:00:00.0,24.23\r\n2014-07-07 02:00:00.0,24.38\r\n2014-07-07 03:00:00.0,24.14\r\n2014-07-07 04:00:00.0,26.02\r\n'
f = open('test.csv', 'w')
f.write(csv_data2)
f.close()

# print csv_file.getvalue()

df = pd.read_csv('test.csv', engine='python', escapechar='\\', parse_dates=[0], index_col=0) #, parse_dates=[0]
df.head()
# Out:
#                      Helsinki
# 2014-07-07 00:00:00     24.43
# 2014-07-07 01:00:00     24.23
# 2014-07-07 02:00:00     24.38
# 2014-07-07 03:00:00     24.14
# 2014-07-07 04:00:00     26.02

# %%
csv_data2 = ',Helsinki\r\n2014-07-07 00:00:00.0,24.43\r\n2014-07-07 01:00:00.0,24.23\r\n2014-07-07 02:00:00.0,24.38\r\n2014-07-07 03:00:00.0,24.14\r\n2014-07-07 04:00:00.0,26.02\r\n'
with open("test2.csv", "w") as csv_file:
    csv_file.write(csv_data2)
    
df = pd.read_csv('test2.csv', engine='python', parse_dates=[0], escapechar='\\', index_col=0)
df.head()
# Out:
#                      Helsinki
# 2014-07-07 00:00:00     24.43
# 2014-07-07 01:00:00     24.23
# 2014-07-07 02:00:00     24.38
# 2014-07-07 03:00:00     24.14
# 2014-07-07 04:00:00     26.02

# %%
import csv
import pandas as pd
testcsv = 'abc,def\r\nass,4.5\r\n203-3-4,6.33'
reader = csv.reader(testcsv.split('\r\n'), delimiter=',')
lst = list(reader)
print lst
idx = list(zip(*lst)[0])
other = list(zip(*lst)[1])
print asdf
print other
df = pd.DataFrame(lst, index=idx)
df
# for row in reader:
#    print '\t'.join(row)
# Out:
# [['abc', 'def'], ['ass', '4.5'], ['203-3-4', '6.33']]
# ['abc', 'ass', '203-3-4']
# ['def', '4.5', '6.33']
#                0     1
# abc          abc   def
# ass          ass   4.5
# 203-3-4  203-3-4  6.33

# %%
import urllib2
url = 'http://localhost:8081/em-app/rest/r/forecastAll/1,3,4/14/2014-07-07/2014-07-10'
response = urllib2.urlopen(url).read()

with open("csvData.csv", "w") as csv_file:
    csv_file.write(response)

df = pd.read_csv('csvData.csv', engine='python', parse_dates=[0], escapechar='\\', index_col=0)
print df.head()
# Out:
#                       Helsinki   Portland     Boston
# 2014-07-07 00:00:00  23.775937  35.194904  38.666659
# 2014-07-07 01:00:00  23.405618  35.933274  39.946558
# 2014-07-07 02:00:00  23.501101  34.553374  39.238789
# 2014-07-07 03:00:00  25.798953  30.053646  35.505744
# 2014-07-07 04:00:00  29.363679  27.471485  33.198696

# %%
df = df / 1000
df
# Out:
#                      Helsinki  Portland    Boston
# 2014-07-07 00:00:00  0.023776  0.035195  0.038667
# 2014-07-07 01:00:00  0.023406  0.035933  0.039947
# 2014-07-07 02:00:00  0.023501  0.034553  0.039239
# 2014-07-07 03:00:00  0.025799  0.030054  0.035506
# 2014-07-07 04:00:00  0.029364  0.027471  0.033199
# 2014-07-07 05:00:00  0.032292  0.024852  0.031121
# 2014-07-07 06:00:00  0.033637  0.022875  0.029355
# 2014-07-07 07:00:00  0.034882  0.021010  0.027786
